# %%
library(data.table) 
library(ggplot2)
library(pheatmap)
library(ComplexHeatmap)
# Out:
# Lade n"otiges Paket: grid
#
# ========================================
# ComplexHeatmap version 2.15.4
# Bioconductor page: http://bioconductor.org/packages/ComplexHeatmap/
# Github page: https://github.com/jokergoo/ComplexHeatmap
# Documentation: http://jokergoo.github.io/ComplexHeatmap-reference
#
# If you use it in published research, please cite either one:
# - Gu, Z. Complex Heatmap Visualization. iMeta 2022.
# - Gu, Z. Complex heatmaps reveal patterns and correlations in multidimensional
#     genomic data. Bioinformatics 2016.
#
#
# The new InteractiveComplexHeatmap package can directly export static
# complex heatmaps into an interactive Shiny app with zero effort. Have a try!
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(ComplexHeatmap))
# ========================================
# ! pheatmap() has been masked by ComplexHeatmap::pheatmap(). Most of the arguments
#    in the original pheatmap() are identically supported in the new function. You
#    can still use the original function by explicitly calling pheatmap::pheatmap().
#
#
#
# Attache Paket: 'ComplexHeatmap'
#
#
# Das folgende Objekt ist maskiert 'package:pheatmap':
#
#     pheatmap

# %% [markdown]
# ## Visualisation of concordance between genetic and hashing deconvolution methods through correlation matrix

# %%
# Load correlation matrix
correlation_gx38 <- fread("../data/pipeline_output/gx38/donor_match/vireo_1_vs_htodemux_1/correlation_res.csv")
correlation_gx38 <- as.data.frame(correlation_gx38)
rownames(correlation_gx38) <- correlation_gx38$V1
correlation_gx38 <- correlation_gx38[,-1]
colnames(correlation_gx38) <- gsub("donor", "Donor-", colnames(correlation_gx38))
rownames(correlation_gx38) <- gsub("-TotalSeqA", "", rownames(correlation_gx38))

# Scale the matrix between -1 and 1
correlation_gx38 <- as.matrix(correlation_gx38)
min_value <- min(correlation_gx38)
max_value <- max(correlation_gx38)

scaled_matrix <- ((correlation_gx38 - min_value) / (max_value - min_value)) * 2 - 1

# Define the color palette and the annotation
newCols <- colorRampPalette(grDevices::rainbow(6))
annoCol <- newCols(6)
names(annoCol) <- colnames(correlation_gx38)
annoCol <- list(category = annoCol)

# Sort the axis
correlation_gx38 <- correlation_gx38[order(row.names(correlation_gx38)), ]

# Heatamp
pheatmap(scaled_matrix, treeheight_row=F, treeheight_col=F, display_numbers=round(correlation_gx38,2), angle_col="0",
         number_color = "black", fontsize = 15, cluster_rows = F, cluster_cols = F) 
         # , filename="S26-concordance-heatmap-v-htodemux-gx38.png", width = 7, height = 5
# Out:
# plot without title

# %%
# Load correlation matrix
correlation_gx38 <- fread("../data/pipeline_output/gx38/donor_match/vireo_1_vs_hashsolo_1/correlation_res.csv")
correlation_gx38 <- na.omit(correlation_gx38)
correlation_gx38 <- as.data.frame(correlation_gx38)
rownames(correlation_gx38) <- correlation_gx38$V1
correlation_gx38 <- correlation_gx38[,-1]
colnames(correlation_gx38) <- gsub("donor", "Donor-", colnames(correlation_gx38))
rownames(correlation_gx38) <- gsub("_TotalSeqA", "", rownames(correlation_gx38))

# Scale the matrix between -1 and 1

correlation_gx38 <- as.matrix(correlation_gx38)

min_value <- min(correlation_gx38)
max_value <- max(correlation_gx38)

scaled_matrix <- ((correlation_gx38 - min_value) / (max_value - min_value)) * 2 - 1

# Define the color palette and the annotation
newCols <- colorRampPalette(grDevices::rainbow(6))
annoCol <- newCols(6)
names(annoCol) <- colnames(correlation_gx38)
annoCol <- list(category = annoCol)

# Sort the axis
correlation_gx38 <- correlation_gx38[order(row.names(correlation_gx38)), ]

# Heatamp
pheatmap(scaled_matrix, treeheight_row=F, treeheight_col=F, display_numbers=round(correlation_gx38,2), angle_col="0",
         number_color = "black", fontsize = 15, cluster_rows = F, cluster_cols = F) 
         #, filename="S27-concordance-heatmap-v-hashsolo-gx38.png", width = 7, height = 4
# Out:
# plot without title

# %%
# Load correlation matrix
correlation_gx38 <- fread("../data/pipeline_output/gx38/donor_match/vireo_1_vs_hashedDrops_1/correlation_res.csv")
#correlation_gx38 <- na.omit(correlation_gx38)
correlation_gx38 <- as.data.frame(correlation_gx38)
rownames(correlation_gx38) <- correlation_gx38$V1
correlation_gx38 <- correlation_gx38[,-1]
colnames(correlation_gx38) <- gsub("donor", "Donor-", colnames(correlation_gx38))
rownames(correlation_gx38) <- paste0("Hash45", rownames(correlation_gx38))

# Scale the matrix between -1 and 1

correlation_gx38 <- as.matrix(correlation_gx38)

min_value <- min(correlation_gx38)
max_value <- max(correlation_gx38)

scaled_matrix <- ((correlation_gx38 - min_value) / (max_value - min_value)) * 2 - 1

# Define the color palette and the annotation
newCols <- colorRampPalette(grDevices::rainbow(6))
annoCol <- newCols(6)
names(annoCol) <- colnames(correlation_gx38)
annoCol <- list(category = annoCol)

# Sort the axis
correlation_gx38 <- correlation_gx38[order(row.names(correlation_gx38)), ]

# Heatamp
pheatmap(scaled_matrix, treeheight_row=F, treeheight_col=F, display_numbers=round(correlation_gx38,2), angle_col="0",
         number_color = "black", fontsize = 15, cluster_rows = F, cluster_cols = F) 
         # , filename="S28-concordance-heatmap-v-hashedDrops-gx38.png", width = 7, height = 5
# Out:
# plot without title

# %%
# Load correlation matrix
correlation_gx38 <- fread("../data/pipeline_output/gx38/donor_match/vireo_1_vs_demuxem_1/correlation_res.csv")
correlation_gx38 <- as.data.frame(correlation_gx38)
rownames(correlation_gx38) <- correlation_gx38$V1
correlation_gx38 <- correlation_gx38[,-1]
colnames(correlation_gx38) <- gsub("donor", "Donor-", colnames(correlation_gx38))
rownames(correlation_gx38) <- gsub("_TotalSeqA", "", rownames(correlation_gx38))

# Scale the matrix between -1 and 1

correlation_gx38 <- as.matrix(correlation_gx38)

min_value <- min(correlation_gx38)
max_value <- max(correlation_gx38)

scaled_matrix <- ((correlation_gx38 - min_value) / (max_value - min_value)) * 2 - 1

# Define the color palette and the annotation
newCols <- colorRampPalette(grDevices::rainbow(6))
annoCol <- newCols(6)
names(annoCol) <- colnames(correlation_gx38)
annoCol <- list(category = annoCol)

# Sort the axis
correlation_gx38 <- correlation_gx38[order(row.names(correlation_gx38)), ]

# Heatamp
pheatmap(scaled_matrix, treeheight_row=F, treeheight_col=F, display_numbers=round(correlation_gx38,2), angle_col="0",
         number_color = "white", fontsize = 15, cluster_rows = F, cluster_cols = F)
         #, filename="S22-concordance-heatmap-v-demuxem-gx38.png", width = 7, height = 5
# Out:
# plot without title

# %%
# Load correlation matrix
correlation_gx38 <- fread("../data/pipeline_output/gx38/donor_match/vireo_1_vs_multiseq_1/correlation_res.csv")
correlation_gx38 <- as.data.frame(correlation_gx38)
rownames(correlation_gx38) <- correlation_gx38$V1
correlation_gx38 <- correlation_gx38[,-1]
colnames(correlation_gx38) <- gsub("donor", "Donor-", colnames(correlation_gx38))
rownames(correlation_gx38) <- gsub("-TotalSeqA", "", rownames(correlation_gx38))

# Scale the matrix between -1 and 1

correlation_gx38 <- as.matrix(correlation_gx38)

min_value <- min(correlation_gx38)
max_value <- max(correlation_gx38)

scaled_matrix <- ((correlation_gx38 - min_value) / (max_value - min_value)) * 2 - 1

# Define the color palette and the annotation
newCols <- colorRampPalette(grDevices::rainbow(6))
annoCol <- newCols(6)
names(annoCol) <- colnames(correlation_gx38)
annoCol <- list(category = annoCol)

# Sort the axis
correlation_gx38 <- correlation_gx38[order(row.names(correlation_gx38)), ]

# Heatamp
pheatmap(scaled_matrix, treeheight_row=F, treeheight_col=F, display_numbers=round(correlation_gx38,2), angle_col="0",
         number_color = "white", fontsize = 15, cluster_rows = F, cluster_cols = F) 
         #, filename="S30-concordance-heatmap-v-multiseq-gx38.png", width = 7, height = 5
# Out:
# plot without title

# %% [markdown]
# ### Summarize the donor matching result

# %%
all_score <- fread("../data/pipeline_output/gx38/donor_match/score_record.csv")
all_score
# Out:
#    best_method1 best_method2  score      matched_donor remain_na
# 1  freemuxlet_1 hashsolo_1    0.05483659 2              TRUE
# 2  freemuxlet_1 demuxem_1     0.69586963 6             FALSE
# 3  freemuxlet_1 hashedDrops_1 0.58918990 6             FALSE
# 4  freemuxlet_1 htodemux_1    0.33886509 5              TRUE
# 5  freemuxlet_1 multiseq_1    0.57725831 6             FALSE
# 6  scsplit_1    hashsolo_1    0.04484537 2              TRUE
# 7  scsplit_1    demuxem_1     0.18753518 4              TRUE
# 8  scsplit_1    hashedDrops_1 0.23599146 5              TRUE
# 9  scsplit_1    htodemux_1    0.07419026 3              TRUE
# 10 scsplit_1    multiseq_1    0.16219165 4              TRUE
# 11 souporcell_1 hashsolo_1    0.08439701 2              TRUE
# 12 souporcell_1 demuxem_1     0.71297907 6             FALSE
# 13 souporcell_1 hashedDrops_1 0.54839323 5              TRUE
# 14 souporcell_1 htodemux_1    0.34227231 5              TRUE
# 15 souporcell_1 multiseq_1    0.58543743 6             FALSE
# 16 vireo_1      hashsolo_1    0.05064408 2              TRUE
# 17 vireo_1      demuxem_1     0.72281323 6             FALSE
# 18 vireo_1      hashedDrops_1 0.49989631 4              TRUE
# 19 vireo_1      htodemux_1    0.32887246 4              TRUE
# 20 vireo_1      multiseq_1    0.60395260 6             FALSE

# %%
score_matrix <- reshape(all_score[,1:3], idvar = "best_method1", timevar ="best_method2", direction = "wide")
score_matrix
# Out:
#   best_method1 score.hashsolo_1 score.demuxem_1 score.hashedDrops_1
# 1 freemuxlet_1 0.05483659       0.6958696       0.5891899
# 2 scsplit_1    0.04484537       0.1875352       0.2359915
# 3 souporcell_1 0.08439701       0.7129791       0.5483932
# 4 vireo_1      0.05064408       0.7228132       0.4998963
#   score.htodemux_1 score.multiseq_1
# 1 0.33886509       0.5772583
# 2 0.07419026       0.1621916
# 3 0.34227231       0.5854374
# 4 0.32887246       0.6039526

# %%
score_matrix <- score_matrix[, -1]
score_matrix <- as.matrix(score_matrix)
colnames(score_matrix) <- c("HashSolo", "DemuxEM", "hashedDrops", "HTODemux", "Multiseq")
rownames(score_matrix) <- c("Freemuxlet", "scSplit", "Souporcell", "Vireo")
score_matrix  <- score_matrix[, c("DemuxEM", "Multiseq", "HashSolo", "HTODemux", "hashedDrops")]
score_matrix
# Out:
#            DemuxEM   Multiseq  HashSolo   HTODemux   hashedDrops
# Freemuxlet 0.6958696 0.5772583 0.05483659 0.33886509 0.5891899
# scSplit    0.1875352 0.1621916 0.04484537 0.07419026 0.2359915
# Souporcell 0.7129791 0.5854374 0.08439701 0.34227231 0.5483932
# Vireo      0.7228132 0.6039526 0.05064408 0.32887246 0.4998963

# %%
#pdf("heatmap_donor_match_gx38.pdf",width=11,height=8)
cpalette = circlize::colorRamp2(c(0,0.5,1), hcl.colors(4, "Blues 3", rev = T)[1:3])
options(repr.plot.width=12, repr.plot.height=8)

ht <- Heatmap(score_matrix, name = "Matching score", cluster_rows = F, show_column_dend = F, 
        col = cpalette, border = TRUE,
        column_names_gp = grid::gpar(fontsize = 20),
        row_names_gp = grid::gpar(fontsize = 20),
        column_order = sort(colnames(score_matrix)),
        column_names_rot = 45,
        heatmap_legend_param = list(
          labels_gp = gpar(fontsize = 17),
          title_gp = gpar(fontsize = 17)),
        cell_fun = function(j, i, x, y, width, height, fill) {
          if ((i %in% c(1,3,4) & j %in% c(1,2)) || i == 1 & j == 5)
            grid.text(sprintf("%.2f", score_matrix[i, j]), x, y, 
              gp = gpar(fontsize = 15, col = "red"))
          else{
            grid.text(sprintf("%.2f", score_matrix[i, j]), x, y, gp = gpar(fontsize = 15, col = "black"))
          }
        }) 
lgd_list = list(
  Legend(labels = c("Not all matched", "All matched"), 
    title = "Matched donors", legend_gp = gpar(fill = 1:2),
    title_gp = gpar(fontsize = 15),
    labels_gp = gpar(fontsize = 15)))
draw(ht, heatmap_legend_list = lgd_list,heatmap_legend_side = "right", padding = unit(c(2, 20, 2, 2), "mm") )  
#dev.off()
# Out:
# plot without title
